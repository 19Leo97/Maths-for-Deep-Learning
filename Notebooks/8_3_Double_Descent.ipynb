# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 204, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 204 (delta 47), reused 60 (delta 41), pack-reused 128
# Receiving objects: 100% (204/204), 8.42 MiB | 12.46 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
#   * Prediction: Maybe the training error will become zero at 100 hidden variables
#   * Reality: Training error became zero roughly at 40 hidden variables.
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
#   * Prediction: At 40 hidden variables
#   * Reality: Roughly at 20 hidden variables
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#   * Prediction: At 80 hidden variables
#   * Reality: Roughly at 50 hidden variables

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301491, train error 89.22,  test loss 2.302229, test error 89.85
# Epoch   100, train loss 2.110568, train error 79.45,  test loss 2.045537, test error 77.62
# Epoch   200, train loss 1.923284, train error 72.07,  test loss 1.754416, test error 70.03
# Epoch   300, train loss 1.916866, train error 71.10,  test loss 1.747380, test error 69.12
# Epoch   400, train loss 1.915622, train error 70.95,  test loss 1.745090, test error 68.85
# Epoch   500, train loss 1.914995, train error 71.47,  test loss 1.740708, test error 69.38
# Epoch   600, train loss 1.918509, train error 71.80,  test loss 1.735309, test error 69.85
# Epoch   700, train loss 1.916258, train error 71.55,  test loss 1.734218, test error 68.97
# Epoch   800, train loss 1.915278, train error 71.10,  test loss 1.743498, test error 68.43
# Epoch   900, train loss 1.914466, train error 71.22,  test loss 1.736908, test error 68.47
# Training model with   4 hidden variables
# Epoch     0, train loss 2.305291, train error 89.32,  test loss 2.301460, test error 88.82
# Epoch   100, train loss 1.865851, train error 67.75,  test loss 1.710390, test error 65.30
# Epoch   200, train loss 1.791821, train error 63.38,  test loss 1.611288, test error 59.92
# Epoch   300, train loss 1.762428, train error 62.67,  test loss 1.578799, test error 59.70
# Epoch   400, train loss 1.747542, train error 62.12,  test loss 1.572846, test error 58.78
# Epoch   500, train loss 1.745825, train error 63.10,  test loss 1.574074, test error 59.35
# Epoch   600, train loss 1.740309, train error 61.80,  test loss 1.558475, test error 58.55
# Epoch   700, train loss 1.730726, train error 61.33,  test loss 1.555484, test error 58.35
# Epoch   800, train loss 1.727112, train error 60.95,  test loss 1.547687, test error 57.90
# Epoch   900, train loss 1.729786, train error 61.35,  test loss 1.551703, test error 58.70
# Training model with   6 hidden variables
# Epoch     0, train loss 2.292218, train error 88.20,  test loss 2.291854, test error 88.80
# Epoch   100, train loss 1.736439, train error 62.60,  test loss 1.577247, test error 61.40
# Epoch   200, train loss 1.680162, train error 60.40,  test loss 1.507495, test error 58.75
# Epoch   300, train loss 1.662609, train error 60.38,  test loss 1.504910, test error 58.72
# Epoch   400, train loss 1.653808, train error 60.45,  test loss 1.516823, test error 58.62
# Epoch   500, train loss 1.648688, train error 60.15,  test loss 1.521886, test error 58.17
# Epoch   600, train loss 1.641360, train error 59.25,  test loss 1.510904, test error 58.83
# Epoch   700, train loss 1.637144, train error 58.53,  test loss 1.507416, test error 57.40
# Epoch   800, train loss 1.635105, train error 59.30,  test loss 1.516934, test error 58.10
# Epoch   900, train loss 1.627131, train error 58.05,  test loss 1.511724, test error 58.08
# Training model with   8 hidden variables
# Epoch     0, train loss 2.191162, train error 81.50,  test loss 2.170489, test error 81.15
# Epoch   100, train loss 1.610458, train error 56.40,  test loss 1.428898, test error 53.65
# Epoch   200, train loss 1.510996, train error 51.08,  test loss 1.281046, test error 47.08
# Epoch   300, train loss 1.496101, train error 50.38,  test loss 1.282688, test error 46.97
# Epoch   400, train loss 1.480026, train error 50.55,  test loss 1.273208, test error 46.30
# Epoch   500, train loss 1.471243, train error 49.88,  test loss 1.269708, test error 46.28
# Epoch   600, train loss 1.460604, train error 49.33,  test loss 1.268286, test error 46.92
# Epoch   700, train loss 1.453812, train error 49.17,  test loss 1.260714, test error 46.62
# Epoch   800, train loss 1.456342, train error 49.28,  test loss 1.259994, test error 46.53
# Epoch   900, train loss 1.448473, train error 49.40,  test loss 1.260149, test error 45.85
# Training model with  10 hidden variables
# Epoch     0, train loss 2.216628, train error 83.88,  test loss 2.186753, test error 82.35
# Epoch   100, train loss 1.531025, train error 51.22,  test loss 1.349399, test error 49.40
# Epoch   200, train loss 1.462838, train error 48.38,  test loss 1.262797, test error 45.92
# Epoch   300, train loss 1.442998, train error 47.78,  test loss 1.264932, test error 47.03
# Epoch   400, train loss 1.426121, train error 47.58,  test loss 1.268314, test error 47.80
# Epoch   500, train loss 1.409710, train error 47.00,  test loss 1.257804, test error 47.30
# Epoch   600, train loss 1.398204, train error 46.80,  test loss 1.274146, test error 47.03
# Epoch   700, train loss 1.392168, train error 46.60,  test loss 1.270938, test error 46.95
# Epoch   800, train loss 1.383999, train error 46.62,  test loss 1.289116, test error 47.38
# Epoch   900, train loss 1.383777, train error 46.17,  test loss 1.295318, test error 47.42
# Training model with  14 hidden variables
# Epoch     0, train loss 2.271457, train error 82.43,  test loss 2.265092, test error 82.72
# Epoch   100, train loss 1.510947, train error 52.20,  test loss 1.449813, test error 55.42
# Epoch   200, train loss 1.453631, train error 50.00,  test loss 1.471594, test error 55.22
# Epoch   300, train loss 1.414388, train error 48.10,  test loss 1.477528, test error 54.92
# Epoch   400, train loss 1.386892, train error 47.05,  test loss 1.470662, test error 54.62
# Epoch   500, train loss 1.366563, train error 47.12,  test loss 1.477140, test error 54.12
# Epoch   600, train loss 1.354235, train error 46.25,  test loss 1.487276, test error 53.55
# Epoch   700, train loss 1.342653, train error 46.45,  test loss 1.505693, test error 54.10
# Epoch   800, train loss 1.326399, train error 45.62,  test loss 1.498107, test error 53.42
# Epoch   900, train loss 1.325318, train error 45.75,  test loss 1.510947, test error 53.92
# Training model with  18 hidden variables
# Epoch     0, train loss 2.236771, train error 82.82,  test loss 2.205583, test error 82.32
# Epoch   100, train loss 1.403590, train error 48.17,  test loss 1.366044, test error 50.35
# Epoch   200, train loss 1.290719, train error 43.90,  test loss 1.349637, test error 50.35
# Epoch   300, train loss 1.246727, train error 42.55,  test loss 1.380255, test error 50.28
# Epoch   400, train loss 1.219658, train error 41.45,  test loss 1.400344, test error 50.72
# Epoch   500, train loss 1.209609, train error 40.08,  test loss 1.437584, test error 51.08
# Epoch   600, train loss 1.201576, train error 40.60,  test loss 1.453882, test error 51.28
# Epoch   700, train loss 1.189623, train error 39.85,  test loss 1.474410, test error 51.70
# Epoch   800, train loss 1.178827, train error 39.60,  test loss 1.496549, test error 51.85
# Epoch   900, train loss 1.168050, train error 39.62,  test loss 1.513532, test error 51.60
# Training model with  22 hidden variables
# Epoch     0, train loss 2.264448, train error 85.00,  test loss 2.252709, test error 84.53
# Epoch   100, train loss 1.299610, train error 42.47,  test loss 1.347239, test error 49.60
# Epoch   200, train loss 1.170227, train error 38.78,  test loss 1.415899, test error 50.05
# Epoch   300, train loss 1.103491, train error 36.33,  test loss 1.503053, test error 51.25
# Epoch   400, train loss 1.069553, train error 35.22,  test loss 1.550483, test error 52.30
# Epoch   500, train loss 1.058648, train error 35.78,  test loss 1.585680, test error 51.50
# Epoch   600, train loss 1.035186, train error 35.10,  test loss 1.645258, test error 53.03
# Epoch   700, train loss 1.030541, train error 34.70,  test loss 1.663608, test error 52.70
# Epoch   800, train loss 1.021496, train error 35.47,  test loss 1.686493, test error 52.97
# Epoch   900, train loss 1.016580, train error 35.18,  test loss 1.731387, test error 53.62
# Training model with  26 hidden variables
# Epoch     0, train loss 2.221539, train error 83.32,  test loss 2.181512, test error 81.62
# Epoch   100, train loss 1.215090, train error 39.83,  test loss 1.288270, test error 47.72
# Epoch   200, train loss 1.069563, train error 35.60,  test loss 1.394807, test error 49.40
# Epoch   300, train loss 0.988385, train error 32.38,  test loss 1.524428, test error 50.33
# Epoch   400, train loss 0.954566, train error 31.38,  test loss 1.646886, test error 51.78
# Epoch   500, train loss 0.912533, train error 30.78,  test loss 1.745985, test error 52.97
# Epoch   600, train loss 0.890073, train error 30.28,  test loss 1.829554, test error 52.50
# Epoch   700, train loss 0.873330, train error 29.72,  test loss 1.914805, test error 53.92
# Epoch   800, train loss 0.863631, train error 29.62,  test loss 1.977276, test error 53.62
# Epoch   900, train loss 0.863991, train error 29.72,  test loss 2.080504, test error 54.72
# Training model with  30 hidden variables
# Epoch     0, train loss 2.186504, train error 80.60,  test loss 2.156961, test error 78.60
# Epoch   100, train loss 1.096244, train error 35.25,  test loss 1.299548, test error 47.62
# Epoch   200, train loss 0.922262, train error 29.72,  test loss 1.509255, test error 50.97
# Epoch   300, train loss 0.832670, train error 26.62,  test loss 1.720837, test error 51.92
# Epoch   400, train loss 0.776765, train error 25.18,  test loss 1.886336, test error 52.47
# Epoch   500, train loss 0.752576, train error 25.25,  test loss 2.042974, test error 53.88
# Epoch   600, train loss 0.717434, train error 23.00,  test loss 2.138947, test error 53.50
# Epoch   700, train loss 0.698120, train error 23.70,  test loss 2.267020, test error 53.50
# Epoch   800, train loss 0.681344, train error 22.95,  test loss 2.395309, test error 54.92
# Epoch   900, train loss 0.667570, train error 22.93,  test loss 2.551212, test error 55.83
# Training model with  35 hidden variables
# Epoch     0, train loss 2.134773, train error 78.95,  test loss 2.083675, test error 77.55
# Epoch   100, train loss 1.058944, train error 34.00,  test loss 1.356834, test error 49.08
# Epoch   200, train loss 0.823850, train error 27.47,  test loss 1.651549, test error 51.00
# Epoch   300, train loss 0.698909, train error 23.85,  test loss 2.049611, test error 52.85
# Epoch   400, train loss 0.641012, train error 21.70,  test loss 2.393150, test error 53.85
# Epoch   500, train loss 0.569917, train error 19.53,  test loss 2.700726, test error 54.40
# Epoch   600, train loss 0.582195, train error 20.35,  test loss 3.017872, test error 56.10
# Epoch   700, train loss 0.514303, train error 18.22,  test loss 3.281353, test error 55.00
# Epoch   800, train loss 0.473581, train error 16.18,  test loss 3.601935, test error 56.38
# Epoch   900, train loss 0.465866, train error 16.05,  test loss 3.906174, test error 56.33
# Training model with  40 hidden variables
# Epoch     0, train loss 2.085635, train error 76.65,  test loss 2.006419, test error 75.53
# Epoch   100, train loss 0.919394, train error 30.20,  test loss 1.446260, test error 50.78
# Epoch   200, train loss 0.626053, train error 20.47,  test loss 1.978678, test error 53.33
# Epoch   300, train loss 0.478129, train error 15.70,  test loss 2.664247, test error 54.62
# Epoch   400, train loss 0.423534, train error 14.53,  test loss 3.398350, test error 55.60
# Epoch   500, train loss 0.388217, train error 12.97,  test loss 4.183407, test error 56.28
# Epoch   600, train loss 0.284154, train error 9.03,  test loss 4.988644, test error 57.50
# Epoch   700, train loss 0.298979, train error 10.90,  test loss 5.878087, test error 57.75
# Epoch   800, train loss 0.260657, train error 9.00,  test loss 6.524938, test error 57.72
# Epoch   900, train loss 0.251634, train error 8.75,  test loss 7.209671, test error 57.75
# Training model with  45 hidden variables
# Epoch     0, train loss 2.150705, train error 80.40,  test loss 2.133209, test error 79.55
# Epoch   100, train loss 0.806700, train error 25.60,  test loss 1.541384, test error 51.22
# Epoch   200, train loss 0.493576, train error 16.18,  test loss 2.361137, test error 55.22
# Epoch   300, train loss 0.327078, train error 10.38,  test loss 3.408271, test error 56.72
# Epoch   400, train loss 0.243371, train error 7.93,  test loss 4.601661, test error 57.05
# Epoch   500, train loss 0.236754, train error 8.95,  test loss 6.036726, test error 58.15
# Epoch   600, train loss 0.124430, train error 3.85,  test loss 7.032518, test error 57.17
# Epoch   700, train loss 0.018633, train error 0.00,  test loss 8.120966, test error 57.72
# Epoch   800, train loss 0.009372, train error 0.00,  test loss 9.022939, test error 57.85
# Epoch   900, train loss 0.006609, train error 0.00,  test loss 9.633654, test error 58.15
# Training model with  50 hidden variables
# Epoch     0, train loss 2.127769, train error 78.93,  test loss 2.077771, test error 76.62
# Epoch   100, train loss 0.720767, train error 23.07,  test loss 1.575645, test error 51.60
# Epoch   200, train loss 0.351415, train error 10.30,  test loss 2.705968, test error 54.42
# Epoch   300, train loss 0.161132, train error 3.93,  test loss 4.165231, test error 54.72
# Epoch   400, train loss 0.041491, train error 0.07,  test loss 5.752005, test error 55.10
# Epoch   500, train loss 0.013830, train error 0.00,  test loss 6.799513, test error 55.95
# Epoch   600, train loss 0.008935, train error 0.00,  test loss 7.455368, test error 56.05
# Epoch   700, train loss 0.006306, train error 0.00,  test loss 7.942986, test error 56.15
# Epoch   800, train loss 0.004853, train error 0.00,  test loss 8.333403, test error 56.33
# Epoch   900, train loss 0.003902, train error 0.00,  test loss 8.653762, test error 56.28
# Training model with  55 hidden variables
# Epoch     0, train loss 2.062234, train error 77.93,  test loss 2.013529, test error 76.97
# Epoch   100, train loss 0.637916, train error 20.25,  test loss 1.762928, test error 51.85
# Epoch   200, train loss 0.225569, train error 5.43,  test loss 3.183861, test error 54.65
# Epoch   300, train loss 0.043372, train error 0.05,  test loss 5.104458, test error 56.33
# Epoch   400, train loss 0.015779, train error 0.00,  test loss 6.257251, test error 56.55
# Epoch   500, train loss 0.008808, train error 0.00,  test loss 6.944314, test error 56.85
# Epoch   600, train loss 0.006044, train error 0.00,  test loss 7.440342, test error 56.92
# Epoch   700, train loss 0.004518, train error 0.00,  test loss 7.824506, test error 56.92
# Epoch   800, train loss 0.003569, train error 0.00,  test loss 8.138037, test error 57.17
# Epoch   900, train loss 0.002940, train error 0.00,  test loss 8.410059, test error 57.25
# Training model with  60 hidden variables
# Epoch     0, train loss 2.058963, train error 76.30,  test loss 2.023045, test error 76.78
# Epoch   100, train loss 0.519765, train error 15.05,  test loss 1.793820, test error 51.62
# Epoch   200, train loss 0.091446, train error 0.70,  test loss 3.640968, test error 55.28
# Epoch   300, train loss 0.017814, train error 0.00,  test loss 4.923837, test error 55.05
# Epoch   400, train loss 0.008769, train error 0.00,  test loss 5.602419, test error 54.90
# Epoch   500, train loss 0.005669, train error 0.00,  test loss 6.059669, test error 55.25
# Epoch   600, train loss 0.004098, train error 0.00,  test loss 6.395599, test error 55.35
# Epoch   700, train loss 0.003169, train error 0.00,  test loss 6.669300, test error 55.55
# Epoch   800, train loss 0.002557, train error 0.00,  test loss 6.891796, test error 55.33
# Epoch   900, train loss 0.002139, train error 0.00,  test loss 7.082074, test error 55.28
# Training model with  70 hidden variables
# Epoch     0, train loss 2.091710, train error 78.10,  test loss 2.051968, test error 78.07
# Epoch   100, train loss 0.355131, train error 8.12,  test loss 1.931865, test error 52.03
# Epoch   200, train loss 0.030198, train error 0.03,  test loss 3.550806, test error 52.08
# Epoch   300, train loss 0.010401, train error 0.00,  test loss 4.273259, test error 52.20
# Epoch   400, train loss 0.005863, train error 0.00,  test loss 4.696779, test error 52.12
# Epoch   500, train loss 0.003970, train error 0.00,  test loss 4.987018, test error 52.10
# Epoch   600, train loss 0.002940, train error 0.00,  test loss 5.207002, test error 51.92
# Epoch   700, train loss 0.002316, train error 0.00,  test loss 5.385906, test error 52.08
# Epoch   800, train loss 0.001892, train error 0.00,  test loss 5.537453, test error 51.97
# Epoch   900, train loss 0.001595, train error 0.00,  test loss 5.665674, test error 51.92
# Training model with  80 hidden variables
# Epoch     0, train loss 2.021928, train error 73.75,  test loss 1.959056, test error 73.43
# Epoch   100, train loss 0.253437, train error 5.10,  test loss 2.190727, test error 53.78
# Epoch   200, train loss 0.020670, train error 0.00,  test loss 3.553227, test error 53.25
# Epoch   300, train loss 0.008091, train error 0.00,  test loss 4.136355, test error 53.22
# Epoch   400, train loss 0.004788, train error 0.00,  test loss 4.483499, test error 53.10
# Epoch   500, train loss 0.003312, train error 0.00,  test loss 4.733578, test error 53.15
# Epoch   600, train loss 0.002490, train error 0.00,  test loss 4.921530, test error 53.30
# Epoch   700, train loss 0.001977, train error 0.00,  test loss 5.077995, test error 53.15
# Epoch   800, train loss 0.001629, train error 0.00,  test loss 5.209713, test error 53.30
# Epoch   900, train loss 0.001378, train error 0.00,  test loss 5.322539, test error 53.20
# Training model with  90 hidden variables
# Epoch     0, train loss 2.026808, train error 74.80,  test loss 1.962528, test error 74.28
# Epoch   100, train loss 0.146352, train error 1.28,  test loss 2.131293, test error 49.92
# Epoch   200, train loss 0.014675, train error 0.00,  test loss 3.226513, test error 50.30
# Epoch   300, train loss 0.006366, train error 0.00,  test loss 3.656059, test error 50.17
# Epoch   400, train loss 0.003897, train error 0.00,  test loss 3.920538, test error 50.08
# Epoch   500, train loss 0.002740, train error 0.00,  test loss 4.107312, test error 50.03
# Epoch   600, train loss 0.002084, train error 0.00,  test loss 4.256183, test error 50.08
# Epoch   700, train loss 0.001665, train error 0.00,  test loss 4.378865, test error 50.03
# Epoch   800, train loss 0.001379, train error 0.00,  test loss 4.480086, test error 50.08
# Epoch   900, train loss 0.001172, train error 0.00,  test loss 4.567893, test error 50.08
# Training model with 100 hidden variables
# Epoch     0, train loss 2.016020, train error 74.90,  test loss 1.948995, test error 75.18
# Epoch   100, train loss 0.092510, train error 0.22,  test loss 2.269784, test error 52.80
# Epoch   200, train loss 0.012460, train error 0.00,  test loss 3.140350, test error 52.38
# Epoch   300, train loss 0.005823, train error 0.00,  test loss 3.510769, test error 52.50
# Epoch   400, train loss 0.003621, train error 0.00,  test loss 3.736583, test error 52.67
# Epoch   500, train loss 0.002571, train error 0.00,  test loss 3.905172, test error 52.78
# Epoch   600, train loss 0.001969, train error 0.00,  test loss 4.040146, test error 52.78
# Epoch   700, train loss 0.001582, train error 0.00,  test loss 4.148560, test error 52.88
# Epoch   800, train loss 0.001315, train error 0.00,  test loss 4.241048, test error 53.00
# Epoch   900, train loss 0.001119, train error 0.00,  test loss 4.320859, test error 52.97
# Training model with 120 hidden variables
# Epoch     0, train loss 1.980440, train error 72.35,  test loss 1.918585, test error 74.07
# Epoch   100, train loss 0.051004, train error 0.00,  test loss 2.276212, test error 50.58
# Epoch   200, train loss 0.009455, train error 0.00,  test loss 2.915199, test error 50.97
# Epoch   300, train loss 0.004662, train error 0.00,  test loss 3.204792, test error 51.08
# Epoch   400, train loss 0.002985, train error 0.00,  test loss 3.390956, test error 51.25
# Epoch   500, train loss 0.002154, train error 0.00,  test loss 3.527051, test error 51.20
# Epoch   600, train loss 0.001664, train error 0.00,  test loss 3.636435, test error 51.17
# Epoch   700, train loss 0.001346, train error 0.00,  test loss 3.727484, test error 51.35
# Epoch   800, train loss 0.001124, train error 0.00,  test loss 3.803401, test error 51.40
# Epoch   900, train loss 0.000961, train error 0.00,  test loss 3.870915, test error 51.30
# Training model with 140 hidden variables
# Epoch     0, train loss 1.966946, train error 71.82,  test loss 1.884176, test error 72.40
# Epoch   100, train loss 0.036007, train error 0.00,  test loss 2.198275, test error 49.72
# Epoch   200, train loss 0.008104, train error 0.00,  test loss 2.707004, test error 49.08
# Epoch   300, train loss 0.004154, train error 0.00,  test loss 2.941734, test error 49.10
# Epoch   400, train loss 0.002702, train error 0.00,  test loss 3.097630, test error 49.00
# Epoch   500, train loss 0.001965, train error 0.00,  test loss 3.213672, test error 49.03
# Epoch   600, train loss 0.001529, train error 0.00,  test loss 3.305201, test error 49.08
# Epoch   700, train loss 0.001242, train error 0.00,  test loss 3.381422, test error 49.10
# Epoch   800, train loss 0.001040, train error 0.00,  test loss 3.445878, test error 49.12
# Epoch   900, train loss 0.000891, train error 0.00,  test loss 3.502689, test error 49.10
# Training model with 160 hidden variables
# Epoch     0, train loss 1.965935, train error 73.25,  test loss 1.889586, test error 72.38
# Epoch   100, train loss 0.028320, train error 0.00,  test loss 2.164972, test error 49.92
# Epoch   200, train loss 0.007136, train error 0.00,  test loss 2.576333, test error 49.58
# Epoch   300, train loss 0.003754, train error 0.00,  test loss 2.782158, test error 49.60
# Epoch   400, train loss 0.002470, train error 0.00,  test loss 2.915998, test error 49.53
# Epoch   500, train loss 0.001809, train error 0.00,  test loss 3.017286, test error 49.50
# Epoch   600, train loss 0.001413, train error 0.00,  test loss 3.098104, test error 49.60
# Epoch   700, train loss 0.001151, train error 0.00,  test loss 3.165553, test error 49.60
# Epoch   800, train loss 0.000967, train error 0.00,  test loss 3.223178, test error 49.60
# Epoch   900, train loss 0.000830, train error 0.00,  test loss 3.273069, test error 49.62
# Training model with 180 hidden variables
# Epoch     0, train loss 1.937100, train error 71.53,  test loss 1.843246, test error 71.35
# Epoch   100, train loss 0.023994, train error 0.00,  test loss 2.135212, test error 49.08
# Epoch   200, train loss 0.006604, train error 0.00,  test loss 2.508496, test error 49.50
# Epoch   300, train loss 0.003525, train error 0.00,  test loss 2.698932, test error 49.50
# Epoch   400, train loss 0.002336, train error 0.00,  test loss 2.825173, test error 49.50
# Epoch   500, train loss 0.001720, train error 0.00,  test loss 2.919163, test error 49.70
# Epoch   600, train loss 0.001347, train error 0.00,  test loss 2.995319, test error 49.65
# Epoch   700, train loss 0.001100, train error 0.00,  test loss 3.058254, test error 49.67
# Epoch   800, train loss 0.000925, train error 0.00,  test loss 3.112782, test error 49.70
# Epoch   900, train loss 0.000795, train error 0.00,  test loss 3.159724, test error 49.55
# Training model with 200 hidden variables
# Epoch     0, train loss 1.919110, train error 69.97,  test loss 1.832286, test error 69.90
# Epoch   100, train loss 0.020971, train error 0.00,  test loss 2.026968, test error 48.30
# Epoch   200, train loss 0.006028, train error 0.00,  test loss 2.333785, test error 48.03
# Epoch   300, train loss 0.003297, train error 0.00,  test loss 2.494794, test error 47.92
# Epoch   400, train loss 0.002200, train error 0.00,  test loss 2.605940, test error 48.00
# Epoch   500, train loss 0.001628, train error 0.00,  test loss 2.688815, test error 48.12
# Epoch   600, train loss 0.001279, train error 0.00,  test loss 2.755086, test error 48.20
# Epoch   700, train loss 0.001046, train error 0.00,  test loss 2.811114, test error 48.25
# Epoch   800, train loss 0.000881, train error 0.00,  test loss 2.858577, test error 48.22
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.900213, test error 48.22
# Training model with 250 hidden variables
# Epoch     0, train loss 1.897436, train error 67.85,  test loss 1.805697, test error 69.90
# Epoch   100, train loss 0.016848, train error 0.00,  test loss 1.991650, test error 47.85
# Epoch   200, train loss 0.005283, train error 0.00,  test loss 2.247036, test error 47.50
# Epoch   300, train loss 0.002956, train error 0.00,  test loss 2.386621, test error 47.40
# Epoch   400, train loss 0.001996, train error 0.00,  test loss 2.479926, test error 47.20
# Epoch   500, train loss 0.001486, train error 0.00,  test loss 2.552415, test error 47.12
# Epoch   600, train loss 0.001174, train error 0.00,  test loss 2.610955, test error 47.25
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.659430, test error 47.33
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.701497, test error 47.25
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.738356, test error 47.25
# Training model with 300 hidden variables
# Epoch     0, train loss 1.867927, train error 67.45,  test loss 1.777922, test error 68.60
# Epoch   100, train loss 0.014439, train error 0.00,  test loss 1.877705, test error 47.25
# Epoch   200, train loss 0.004813, train error 0.00,  test loss 2.097516, test error 47.20
# Epoch   300, train loss 0.002728, train error 0.00,  test loss 2.218027, test error 47.17
# Epoch   400, train loss 0.001857, train error 0.00,  test loss 2.299184, test error 46.95
# Epoch   500, train loss 0.001389, train error 0.00,  test loss 2.362325, test error 47.00
# Epoch   600, train loss 0.001100, train error 0.00,  test loss 2.413130, test error 46.90
# Epoch   700, train loss 0.000905, train error 0.00,  test loss 2.456048, test error 46.92
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.492680, test error 46.97
# Epoch   900, train loss 0.000662, train error 0.00,  test loss 2.525123, test error 47.05
# Training model with 400 hidden variables
# Epoch     0, train loss 1.840118, train error 65.82,  test loss 1.765702, test error 67.80
# Epoch   100, train loss 0.011582, train error 0.00,  test loss 1.742435, test error 45.12
# Epoch   200, train loss 0.004136, train error 0.00,  test loss 1.914803, test error 45.12
# Epoch   300, train loss 0.002396, train error 0.00,  test loss 2.009478, test error 45.03
# Epoch   400, train loss 0.001651, train error 0.00,  test loss 2.075682, test error 44.92
# Epoch   500, train loss 0.001245, train error 0.00,  test loss 2.126359, test error 44.92
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.167225, test error 44.83
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.202154, test error 44.80
# Epoch   800, train loss 0.000696, train error 0.00,  test loss 2.231992, test error 44.75
# Epoch   900, train loss 0.000603, train error 0.00,  test loss 2.258426, test error 44.62

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
